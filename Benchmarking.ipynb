# %% [markdown]
# Benchmarking Notebook
# ============

# %%
import warnings
warnings.simplefilter(action='ignore')

import pandas as pd
import numpy as np
import os
import time
import random
#import resource

from scipy import stats
from sklearn.linear_model import LogisticRegression
from sklearn import linear_model

import statsmodels.api as sm
import statsmodels.formula.api as smf


# For Visualization
import matplotlib.pyplot as plt
#displays better in jupyter notebooks
# %matplotlib inline

# %% [markdown]
# **File descriptions**
#
#     train - Training set. 10 days of click-through data, ordered chronologically. Non-clicks and clicks are subsampled according to different strategies.
#     test - Test set. 1 day of ads to for testing your model predictions.
#     sampleSubmission.csv - Sample submission file in the correct format, corresponds to the All-0.5 Benchmark.
#
# **Data fields**
#
#     id: ad identifier
#     click: 0/1 for non-click/click
#     hour: format is YYMMDDHH, so 14091123 means 23:00 on Sept. 11, 2014 UTC.
#     C1 -- anonymized categorical variable
#     banner_pos
#     site_id
#     site_domain
#     site_category
#     app_id
#     app_domain
#     app_category
#     device_id
#     device_ip
#     device_model
#     device_type
#     device_conn_type
#     C14-C21 -- anonymized categorical variables

# %% [markdown]
# **Data Source(s):**
#
# https://www.kaggle.com/c/avazu-ctr-prediction/data
#
# https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary.html#avazu

# %%
train=pd.read_csv(os.getcwd()+'\\train.csv')
test=pd.read_csv(os.getcwd()+'\\test.csv')

# %%
train.head()
# Out:
#              id  click      hour    C1  banner_pos   site_id site_domain  \
# 0  1.000009e+18      0  14102100  1005           0  1fbe01fe    f3845767
# 1  1.000017e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 2  1.000037e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 3  1.000064e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 4  1.000068e+19      0  14102100  1005           1  fe8cc448    9166c161
#
#   site_category    app_id app_domain ...  device_type device_conn_type    C14  \
# 0      28905ebd  ecad2386   7801e8d9 ...            1                2  15706
# 1      28905ebd  ecad2386   7801e8d9 ...            1                0  15704
# 2      28905ebd  ecad2386   7801e8d9 ...            1                0  15704
# 3      28905ebd  ecad2386   7801e8d9 ...            1                0  15706
# 4      0569f928  ecad2386   7801e8d9 ...            1                0  18993
#
#    C15  C16   C17  C18  C19     C20  C21
# 0  320   50  1722    0   35      -1   79
# 1  320   50  1722    0   35  100084   79
# 2  320   50  1722    0   35  100084   79
# 3  320   50  1722    0   35  100084   79
# 4  320   50  2161    0   35      -1  157
#
# [5 rows x 24 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40428967 entries, 0 to 40428966
# Data columns (total 24 columns):
# id                  float64
# click               int64
# hour                int64
# C1                  int64
# banner_pos          int64
# site_id             object
# site_domain         object
# site_category       object
# app_id              object
# app_domain          object
# app_category        object
# device_id           object
# device_ip           object
# device_model        object
# device_type         int64
# device_conn_type    int64
# C14                 int64
# C15                 int64
# C16                 int64
# C17                 int64
# C18                 int64
# C19                 int64
# C20                 int64
# C21                 int64
# dtypes: float64(1), int64(14), object(9)
# memory usage: 7.2+ GB

# %%
test.head()
# Out:
#              id      hour    C1  banner_pos   site_id site_domain  \
# 0  1.000017e+19  14103100  1005           0  235ba823    f6ebf28e
# 1  1.000018e+19  14103100  1005           0  1fbe01fe    f3845767
# 2  1.000055e+19  14103100  1005           0  1fbe01fe    f3845767
# 3  1.000109e+19  14103100  1005           0  85f751fd    c4e18dd6
# 4  1.000138e+19  14103100  1005           0  85f751fd    c4e18dd6
#
#   site_category    app_id app_domain app_category ...  device_type  \
# 0      f028772b  ecad2386   7801e8d9     07d7df22 ...            1
# 1      28905ebd  ecad2386   7801e8d9     07d7df22 ...            1
# 2      28905ebd  ecad2386   7801e8d9     07d7df22 ...            1
# 3      50e219e0  51cedd4e   aefc06bd     0f2161f8 ...            1
# 4      50e219e0  9c13b419   2347f47a     f95efa07 ...            1
#
#   device_conn_type    C14  C15  C16   C17  C18  C19     C20  C21
# 0                0   8330  320   50   761    3  175  100075   23
# 1                0  22676  320   50  2616    0   35  100083   51
# 2                0  22676  320   50  2616    0   35  100083   51
# 3                0  18648  320   50  1092    3  809  100156   61
# 4                0  23160  320   50  2667    0   47      -1  221
#
# [5 rows x 23 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4577464 entries, 0 to 4577463
# Data columns (total 23 columns):
# id                  float64
# hour                int64
# C1                  int64
# banner_pos          int64
# site_id             object
# site_domain         object
# site_category       object
# app_id              object
# app_domain          object
# app_category        object
# device_id           object
# device_ip           object
# device_model        object
# device_type         int64
# device_conn_type    int64
# C14                 int64
# C15                 int64
# C16                 int64
# C17                 int64
# C18                 int64
# C19                 int64
# C20                 int64
# C21                 int64
# dtypes: float64(1), int64(13), object(9)
# memory usage: 803.2+ MB

# %% [markdown]
# Site **85f751fd** with greatest number of observations

# %%
pd.Series.value_counts(train['site_id'],ascending=False).head()
# Out:
# 85f751fd    14596137
# 1fbe01fe     6486150
# e151e245     2637747
# d9750ee7      963745
# 5b08c53b      913325
# Name: site_id, dtype: int64

# %% [markdown]
# App **ecad2386** with the greatest number of observations

# %%
pd.Series.value_counts(train['app_id'],ascending=False).head()
# Out:
# ecad2386    25832830
# 92f5800b     1555283
# e2fcccd2     1129016
# febd1138      759098
# 9c13b419      757812
# Name: app_id, dtype: int64

# %% [markdown]
# _________________________

# %% [markdown]
# Data Preprocessing
# =====

# %% [markdown]
# Narrowing focus to a particular site & app
# ------

# %%
#Conversion list from Hex to Integers for modeling
convList=['site_id',
          'site_domain',
          'site_category',
          'app_id',
          'app_domain',
          'app_category',
          'device_id',
          'device_ip',
          'device_model',
         ]

#Conversion function
def convHexInt(dataframe):
    for i in convList:
        dataframe[i]=dataframe[i].apply(lambda x: int(x,16))
    return dataframe

# %% [markdown]
# Restricting data to *site:* **85f751fd**

# %% [markdown]
# **Train**

# %%
Train_85f751fd=train[train['site_id']=='85f751fd']
Train_85f751fd.head()
# Out:
#               id  click      hour    C1  banner_pos   site_id site_domain  \
# 14  1.000252e+19      0  14102100  1005           0  85f751fd    c4e18dd6
# 19  1.000448e+19      0  14102100  1005           0  85f751fd    c4e18dd6
# 25  1.000533e+19      0  14102100  1010           1  85f751fd    c4e18dd6
# 27  1.000561e+19      1  14102100  1005           0  85f751fd    c4e18dd6
# 30  1.000619e+19      0  14102100  1005           0  85f751fd    c4e18dd6
#
#    site_category    app_id app_domain ...  device_type device_conn_type  \
# 14      50e219e0  98fed791   d9b5648e ...            1                0
# 19      50e219e0  66a5f0f3   d9b5648e ...            1                0
# 25      50e219e0  ffc6ffd0   7801e8d9 ...            4                0
# 27      50e219e0  54c5d545   2347f47a ...            1                0
# 30      50e219e0  685d1c4c   2347f47a ...            1                3
#
#       C14  C15  C16   C17  C18  C19     C20  C21
# 14  20984  320   50  2371    0  551      -1   46
# 19  21234  320   50  2434    3  163  100088   61
# 25  21665  320   50  2493    3   35      -1  117
# 27  21611  320   50  2480    3  297  100111   61
# 30  15708  320   50  1722    0   35      -1   79
#
# [5 rows x 24 columns]

# %% [markdown]
# Convert Hex to Integers

# %%
Train_85f751fd=convHexInt(train[train['site_id']=='85f751fd'])
Train_85f751fd.head()
# Out:
#               id  click      hour    C1  banner_pos     site_id  site_domain  \
# 14  1.000252e+19      0  14102100  1005           0  2247578109   3303116246
# 19  1.000448e+19      0  14102100  1005           0  2247578109   3303116246
# 25  1.000533e+19      0  14102100  1010           1  2247578109   3303116246
# 27  1.000561e+19      1  14102100  1005           0  2247578109   3303116246
# 30  1.000619e+19      0  14102100  1005           0  2247578109   3303116246
#
#     site_category      app_id  app_domain ...   device_type  device_conn_type  \
# 14     1356995040  2566838161  3652543630 ...             1                 0
# 19     1356995040  1722151155  3652543630 ...             1                 0
# 25     1356995040  4291231696  2013391065 ...             4                 0
# 27     1356995040  1422251333   591918202 ...             1                 0
# 30     1356995040  1750932556   591918202 ...             1                 3
#
#       C14  C15  C16   C17  C18  C19     C20  C21
# 14  20984  320   50  2371    0  551      -1   46
# 19  21234  320   50  2434    3  163  100088   61
# 25  21665  320   50  2493    3   35      -1  117
# 27  21611  320   50  2480    3  297  100111   61
# 30  15708  320   50  1722    0   35      -1   79
#
# [5 rows x 24 columns]

# %% [markdown]
# **Test**

# %%
Test_85f751fd=test[test['site_id']=='85f751fd']
Test_85f751fd.head()
# Out:
#               id      hour    C1  banner_pos   site_id site_domain  \
# 3   1.000109e+19  14103100  1005           0  85f751fd    c4e18dd6
# 4   1.000138e+19  14103100  1005           0  85f751fd    c4e18dd6
# 7   1.000198e+19  14103100  1005           0  85f751fd    c4e18dd6
# 11  1.000225e+19  14103100  1005           0  85f751fd    c4e18dd6
# 12  1.000227e+19  14103100  1010           7  85f751fd    c4e18dd6
#
#    site_category    app_id app_domain app_category ...  device_type  \
# 3       50e219e0  51cedd4e   aefc06bd     0f2161f8 ...            1
# 4       50e219e0  9c13b419   2347f47a     f95efa07 ...            1
# 7       50e219e0  388d9bfb   2347f47a     cef3e649 ...            1
# 11      50e219e0  2d869bee   d9b5648e     0f2161f8 ...            1
# 12      50e219e0  643e0f88   7801e8d9     0f2161f8 ...            4
#
#    device_conn_type    C14  C15  C16   C17  C18   C19     C20  C21
# 3                 0  18648  320   50  1092    3   809  100156   61
# 4                 0  23160  320   50  2667    0    47      -1  221
# 7                 3  23214  300  250  2675    3   939  100058  100
# 11                0  23866  320   50  2736    0    33  100170  246
# 12                2  21791  320  480  2513    3  1059      -1   68
#
# [5 rows x 23 columns]

# %% [markdown]
# Convert Hex to Integers

# %%
Test_85f751fd=convHexInt(test[test['site_id']=='85f751fd'])    
Test_85f751fd.head()
# Out:
#               id      hour    C1  banner_pos     site_id  site_domain  \
# 3   1.000109e+19  14103100  1005           0  2247578109   3303116246
# 4   1.000138e+19  14103100  1005           0  2247578109   3303116246
# 7   1.000198e+19  14103100  1005           0  2247578109   3303116246
# 11  1.000225e+19  14103100  1005           0  2247578109   3303116246
# 12  1.000227e+19  14103100  1010           7  2247578109   3303116246
#
#     site_category      app_id  app_domain  app_category ...   device_type  \
# 3      1356995040  1372511566  2935752381     253846008 ...             1
# 4      1356995040  2618536985   591918202    4183751175 ...             1
# 7      1356995040   948804603   591918202    3472090697 ...             1
# 11     1356995040   763796462  3652543630     253846008 ...             1
# 12     1356995040  1681788808  2013391065     253846008 ...             4
#
#     device_conn_type    C14  C15  C16   C17  C18   C19     C20  C21
# 3                  0  18648  320   50  1092    3   809  100156   61
# 4                  0  23160  320   50  2667    0    47      -1  221
# 7                  3  23214  300  250  2675    3   939  100058  100
# 11                 0  23866  320   50  2736    0    33  100170  246
# 12                 2  21791  320  480  2513    3  1059      -1   68
#
# [5 rows x 23 columns]

# %% [markdown]
# Restricting data to *app:* **ecad2386**

# %% [markdown]
# **Train**

# %%
Train_ecad2386=train[train['app_id']=='ecad2386']
Train_ecad2386.head()
# Out:
#              id  click      hour    C1  banner_pos   site_id site_domain  \
# 0  1.000009e+18      0  14102100  1005           0  1fbe01fe    f3845767
# 1  1.000017e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 2  1.000037e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 3  1.000064e+19      0  14102100  1005           0  1fbe01fe    f3845767
# 4  1.000068e+19      0  14102100  1005           1  fe8cc448    9166c161
#
#   site_category    app_id app_domain ...  device_type device_conn_type    C14  \
# 0      28905ebd  ecad2386   7801e8d9 ...            1                2  15706
# 1      28905ebd  ecad2386   7801e8d9 ...            1                0  15704
# 2      28905ebd  ecad2386   7801e8d9 ...            1                0  15704
# 3      28905ebd  ecad2386   7801e8d9 ...            1                0  15706
# 4      0569f928  ecad2386   7801e8d9 ...            1                0  18993
#
#    C15  C16   C17  C18  C19     C20  C21
# 0  320   50  1722    0   35      -1   79
# 1  320   50  1722    0   35  100084   79
# 2  320   50  1722    0   35  100084   79
# 3  320   50  1722    0   35  100084   79
# 4  320   50  2161    0   35      -1  157
#
# [5 rows x 24 columns]

# %% [markdown]
# Convert Hex to Integers

# %%
Train_ecad2386=convHexInt(train[train['app_id']=='ecad2386'])
Train_ecad2386.head()
# Out:
#              id  click      hour    C1  banner_pos     site_id  site_domain  \
# 0  1.000009e+18      0  14102100  1005           0   532546046   4085536615
# 1  1.000017e+19      0  14102100  1005           0   532546046   4085536615
# 2  1.000037e+19      0  14102100  1005           0   532546046   4085536615
# 3  1.000064e+19      0  14102100  1005           0   532546046   4085536615
# 4  1.000068e+19      0  14102100  1005           1  4270638152   2439430497
#
#    site_category      app_id  app_domain ...   device_type  device_conn_type  \
# 0      680550077  3970769798  2013391065 ...             1                 2
# 1      680550077  3970769798  2013391065 ...             1                 0
# 2      680550077  3970769798  2013391065 ...             1                 0
# 3      680550077  3970769798  2013391065 ...             1                 0
# 4       90831144  3970769798  2013391065 ...             1                 0
#
#      C14  C15  C16   C17  C18  C19     C20  C21
# 0  15706  320   50  1722    0   35      -1   79
# 1  15704  320   50  1722    0   35  100084   79
# 2  15704  320   50  1722    0   35  100084   79
# 3  15706  320   50  1722    0   35  100084   79
# 4  18993  320   50  2161    0   35      -1  157
#
# [5 rows x 24 columns]

# %% [markdown]
# **Test**

# %%
Test_ecad2386=test[test['app_id']=='ecad2386']
Test_ecad2386.head()
# Out:
#              id      hour    C1  banner_pos   site_id site_domain  \
# 0  1.000017e+19  14103100  1005           0  235ba823    f6ebf28e
# 1  1.000018e+19  14103100  1005           0  1fbe01fe    f3845767
# 2  1.000055e+19  14103100  1005           0  1fbe01fe    f3845767
# 5  1.000152e+19  14103100  1005           1  57fe1b20    5b626596
# 6  1.000191e+19  14103100  1005           0  1fbe01fe    f3845767
#
#   site_category    app_id app_domain app_category ...  device_type  \
# 0      f028772b  ecad2386   7801e8d9     07d7df22 ...            1
# 1      28905ebd  ecad2386   7801e8d9     07d7df22 ...            1
# 2      28905ebd  ecad2386   7801e8d9     07d7df22 ...            1
# 5      f028772b  ecad2386   7801e8d9     07d7df22 ...            1
# 6      28905ebd  ecad2386   7801e8d9     07d7df22 ...            1
#
#   device_conn_type    C14  C15  C16   C17  C18  C19     C20  C21
# 0                0   8330  320   50   761    3  175  100075   23
# 1                0  22676  320   50  2616    0   35  100083   51
# 2                0  22676  320   50  2616    0   35  100083   51
# 5                0   6563  320   50   572    2   39      -1   32
# 6                0  22813  320   50  2647    2   39  100148   23
#
# [5 rows x 23 columns]

# %% [markdown]
# Convert Hex to Integers

# %%
Test_ecad2386=convHexInt(test[test['app_id']=='ecad2386'])
Test_ecad2386.head()
# Out:
#              id      hour    C1  banner_pos     site_id  site_domain  \
# 0  1.000017e+19  14103100  1005           0   593209379   4142658190
# 1  1.000018e+19  14103100  1005           0   532546046   4085536615
# 2  1.000055e+19  14103100  1005           0   532546046   4085536615
# 5  1.000152e+19  14103100  1005           1  1476270880   1533175190
# 6  1.000191e+19  14103100  1005           0   532546046   4085536615
#
#    site_category      app_id  app_domain  app_category ...   device_type  \
# 0     4029183787  3970769798  2013391065     131587874 ...             1
# 1      680550077  3970769798  2013391065     131587874 ...             1
# 2      680550077  3970769798  2013391065     131587874 ...             1
# 5     4029183787  3970769798  2013391065     131587874 ...             1
# 6      680550077  3970769798  2013391065     131587874 ...             1
#
#    device_conn_type    C14  C15  C16   C17  C18  C19     C20  C21
# 0                 0   8330  320   50   761    3  175  100075   23
# 1                 0  22676  320   50  2616    0   35  100083   51
# 2                 0  22676  320   50  2616    0   35  100083   51
# 5                 0   6563  320   50   572    2   39      -1   32
# 6                 0  22813  320   50  2647    2   39  100148   23
#
# [5 rows x 23 columns]

# %%
train=[]
test=[]

# %% [markdown]
# ______________

# %% [markdown]
# ** Logistic Regression (Batch Gradient Descent)**
# ================

# %% [markdown]
# **Outcome**

# %% [markdown]
# *The outcome we are trying to predict*

# %%
y=pd.DataFrame(Train_85f751fd['click']).copy()
y.head()
# Out:
#     click
# 14      0
# 19      0
# 25      0
# 27      1
# 30      0

# %% [markdown]
# **Features**

# %% [markdown]
# *The variables we are going to use to predict the outcome*
#
# *An intercept column was added*

# %%
X=Train_85f751fd.iloc[:,1:].copy()
#X=data.iloc[:,1:].copy()
X['click']=1 #Specifically Adding Intercept "Bias" term
#X.rename(index=str, columns={'click': 'intercept'},inplace=True)
X.drop(['click','site_id','site_domain'], axis=1,inplace=True)
X.head()
# Out:
#         hour    C1  banner_pos  site_category      app_id  app_domain  \
# 14  14102100  1005           0     1356995040  2566838161  3652543630
# 19  14102100  1005           0     1356995040  1722151155  3652543630
# 25  14102100  1010           1     1356995040  4291231696  2013391065
# 27  14102100  1005           0     1356995040  1422251333   591918202
# 30  14102100  1005           0     1356995040  1750932556   591918202
#
#     app_category   device_id   device_ip  device_model  device_type  \
# 14     253846008  2845778250  1844193174    2866043649            1
# 19    3472090697  2845778250  4200640363    3031538839            1
# 25     253846008  4213425475  1770589311    2683280808            4
# 27     253846008  2599974008   707525769    3975219919            1
# 30    2381127546  1788097940  2315340987    2176066856            1
#
#     device_conn_type    C14  C15  C16   C17  C18  C19     C20  C21
# 14                 0  20984  320   50  2371    0  551      -1   46
# 19                 0  21234  320   50  2434    3  163  100088   61
# 25                 0  21665  320   50  2493    3   35      -1  117
# 27                 0  21611  320   50  2480    3  297  100111   61
# 30                 3  15708  320   50  1722    0   35      -1   79

# %% [markdown]
# Turn Pandas Columns to Numpy Arrays

# %%
colNames=list(X.columns)
#m,n = X.shape
y = np.array(y)
X = np.array(X)
#theta = np.array(np.zeros(n).reshape(n,1))

# %% [markdown]
# Predictions of Site and App
# --------

# %% [markdown]
# **Sci-Kit Learn Predicting Site**

# %%
# instantiate a logistic regression model, and fit with X and y
model = LogisticRegression()
model = model.fit(X, y.ravel())

# %%
# check the accuracy on the training set
print('The accuracy of the model (R-Square):',model.score(X, y))
# Out:
# The accuracy of the model (R-Square): 0.8811735598261375

# %%
# what percentage clicked?
y.mean()
# Out:
# 0.11882644017386244

# %%
def modelExp(X):
    return 1 / (1 + np.exp(-X))
#Check=modelExp(X * model.coef_ + model.intercept_).ravel()

# %%
#def modelExp(X):
#return 1 / (1 + np.exp(-X))

#def SciKitLogRegress(X,y):
#    model = linear_model.LogisticRegression(max_iter=100,tol=0.0001,fit_intercept=False,n_jobs=1,C=100000)
#    model.fit(X, y.ravel())
#    Accuracy=model.score(X, y)
#    print('The accuracy of the model (R-Square):',Accuracy)
#    coeff_df = pd.DataFrame(data=list(zip(X.columns, model.coef_[0].T)),columns=['Coefficient','Estimate'])
#    X=np.array(X)
#    modelExpCoeff=modelExp(X * model.coef_ + model.intercept_)#.ravel()
#    Y_mean=y.mean()
#    print('Target average:',Y_mean)
#    return coeff_df#,modelExpCoeff

# %%
coeff_df = pd.DataFrame(data=list(zip(colNames, model.coef_[0].T)),columns=['Coefficient','Estimate'])
coeff_df
# Out:
#          Coefficient      Estimate
# 0               hour -1.485494e-11
# 1                 C1 -1.065513e-15
# 2         banner_pos  7.710398e-19
# 3      site_category -1.429290e-09
# 4             app_id  1.679375e-11
# 5         app_domain -1.232816e-10
# 6       app_category  8.622304e-11
# 7          device_id -2.394132e-11
# 8          device_ip  1.510368e-12
# 9       device_model  1.997202e-11
# 10       device_type -4.051404e-18
# 11  device_conn_type -1.736125e-17
# 12               C14 -7.942380e-14
# 13               C15 -3.565086e-16
# 14               C16  1.536679e-16
# 15               C17 -9.103505e-15
# 16               C18  4.068568e-18
# 17               C19  7.832952e-16
# 18               C20 -4.908669e-13
# 19               C21 -7.272109e-16

# %%
#time_start = time.clock()

# %%
#%%time
#Output,OutputExp=SciKitLogRegress(X,y)
#https://stackoverflow.com/questions/11886862/calculating-computational-time-and-memory-for-a-code-in-python
#resource.getrusage(resource.RUSAGE_SELF).ru_maxrss

# %%
#time_elapsed = (time.clock() - time_start)
#time_elapsed

# %%
#Output

# %%
#modelExpCoeff

# %%
logit_mod=sm.Logit(y,X).fit()
print(logit_mod.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.349447
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:             14596137
# Model:                          Logit   Df Residuals:                 14596122
# Method:                           MLE   Df Model:                           14
# Date:                Fri, 19 Oct 2018   Pseudo R-squ.:                 0.04151
# Time:                        10:21:07   Log-Likelihood:            -5.1006e+06
# converged:                       True   LL-Null:                   -5.3215e+06
#                                         LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0001   2.82e-06     49.689      0.000       0.000       0.000
# x2            -0.2900      0.003   -111.970      0.000      -0.295      -0.285
# x3             0.2072      0.002     99.588      0.000       0.203       0.211
# const      -1.243e-06   2.94e-08    -42.285      0.000    -1.3e-06   -1.19e-06
# x4         -1.952e-11   6.96e-13    -28.052      0.000   -2.09e-11   -1.82e-11
# x5         -5.849e-11   8.09e-13    -72.260      0.000   -6.01e-11   -5.69e-11
# x6          6.416e-11   5.59e-13    114.722      0.000    6.31e-11    6.53e-11
# x7          1.959e-11   9.92e-13     19.747      0.000    1.76e-11    2.15e-11
# x8          1.551e-12   6.65e-13      2.333      0.020    2.48e-13    2.85e-12
# x9          1.284e-11   6.53e-13     19.650      0.000    1.16e-11    1.41e-11
# x10            0.2934      0.005     62.604      0.000       0.284       0.303
# x11           -0.3005      0.001   -340.037      0.000      -0.302      -0.299
# x12        -4.459e-05   8.18e-07    -54.514      0.000   -4.62e-05    -4.3e-05
# x13           -0.0007   3.33e-05    -19.916      0.000      -0.001      -0.001
# x14            0.0020   1.84e-05    108.701      0.000       0.002       0.002
# x15            0.0001   6.86e-06     19.885      0.000       0.000       0.000
# x16           -0.0769      0.001    -96.524      0.000      -0.078      -0.075
# x17        -8.855e-05   2.67e-06    -33.181      0.000   -9.38e-05   -8.33e-05
# x18        -4.253e-06   1.81e-08   -235.611      0.000   -4.29e-06   -4.22e-06
# x19           -0.0025   1.61e-05   -154.181      0.000      -0.003      -0.002
# ==============================================================================

# %%
print(np.exp(logit_mod.params))
# Out:
# [1.00014023 0.7482992  1.23026432 0.99999876 1.         1.
#  1.         1.         1.         1.         1.34095037 0.74045201
#  0.99995541 0.99933629 1.0020005  1.00013635 0.92601491 0.99991145
#  0.99999575 0.99751822]
